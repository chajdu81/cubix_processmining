-- %% [markdown]
-- Selecting data from a table

-- %%
SELECT TOP (3) [customer_id]
      ,[name]
      ,[signup_date]
      ,[country]
  FROM [sql_recap].[dbo].[customers]
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.038
-- <table><tr><th>customer_id</th><th>name</th><th>signup_date</th><th>country</th></tr><tr><td>1</td><td>Dr. Erin Preston DDS</td><td>2020-06-26</td><td>France</td></tr><tr><td>2</td><td>Brad Castro</td><td>2023-03-08</td><td>USA</td></tr><tr><td>3</td><td>Mrs. Erica Smith</td><td>2020-06-22</td><td>Germany</td></tr></table>

-- %%
SELECT count(*) as darab

  FROM [sql_recap].[dbo].[customers]
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.008
-- <table><tr><th>darab</th></tr><tr><td>500</td></tr></table>

-- %%
SELECT max(customer_id) as max_customer_id

  FROM [sql_recap].[dbo].[customers]
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.004
-- <table><tr><th>max_customer_id</th></tr><tr><td>500</td></tr></table>

-- %%
select avg(total_amount) as avg_rendeles, count(*) as rendelesek_szama
from sql_recap.dbo.orders
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.027
-- <table><tr><th>avg_rendeles</th><th>rendelesek_szama</th></tr><tr><td>3160</td><td>3000</td></tr></table>
