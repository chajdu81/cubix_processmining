-- %%
SELECT DISTINCT country
from sql_recap.dbo.customers
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.050
-- <table><tr><th>country</th></tr><tr><td>France</td></tr><tr><td>Germany</td></tr><tr><td>Hungary</td></tr><tr><td>UK</td></tr><tr><td>USA</td></tr></table>

-- %%
SELECT TOP (3) *
FROM sql_recap.dbo.customers
WHERE country = 'France' and YEAR(signup_date)='2020'
ORDER BY signup_date;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.006
-- <table><tr><th>customer_id</th><th>name</th><th>signup_date</th><th>country</th></tr><tr><td>326</td><td>Angela Atkins</td><td>2020-02-01</td><td>France</td></tr><tr><td>41</td><td>David Everett</td><td>2020-03-06</td><td>France</td></tr><tr><td>95</td><td>Zachary Black</td><td>2020-03-30</td><td>France</td></tr></table>

-- %%
SELECT max(cast(trim(replace(product_name, 'Product', '')) as INT)) as 'legnagyobb product id'
from sql_recap.dbo.products

SELECT max(product_name) as 'legnagyobb product id'
from sql_recap.dbo.products
-- Out:
-- (1 row affected)
-- (1 row affected)
-- Total execution time: 00:00:00.016
-- <table><tr><th>legnagyobb product id</th></tr><tr><td>200</td></tr></table>
-- <table><tr><th>legnagyobb product id</th></tr><tr><td>Product 99</td></tr></table>

-- %%
SELECT category, count(*)
from sql_recap.dbo.products
group by category
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.014
-- <table><tr><th>category</th><th>(No column name)</th></tr><tr><td>Books</td><td>42</td></tr><tr><td>Clothing</td><td>35</td></tr><tr><td>Electronics</td><td>41</td></tr><tr><td>Furniture</td><td>41</td></tr><tr><td>Toys</td><td>41</td></tr></table>

-- %%
SELECT *
from sql_recap.dbo.customers
where name = 'James Walker'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.009
-- <table><tr><th>customer_id</th><th>name</th><th>signup_date</th><th>country</th></tr><tr><td>158</td><td>James Walker</td><td>2021-05-20</td><td>UK</td></tr></table>

-- %%
SELECT count(*)
from sql_recap.dbo.customers
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.003
-- <table><tr><th>(No column name)</th></tr><tr><td>500</td></tr></table>
